# %%
import json 
import pandas as pd


path = "/Users/mathias/Desktop/Project_NLP_MVA_23/Datasets/HuCoPA/data/train_initial.json"



with open(path, encoding='utf8') as json_file:
    json_data = json.load(json_file)
    print(json_data)
    for line_idx, example_json in enumerate(json_data):
                #print(type(example_json['id']))
                #example_json=example_json[0]
                label = str(example_json['label']) if 'label' in example_json else None
                #print("===========")
                #print(label)
                #idx = line_idx

                idx = example_json['id']
                print(label, idx)



traininit_data = pd.DataFrame(json_data)
traininit_data.index = traininit_data['id']

#traininit_data.drop('id',axis=1,inplace=True)


traininit_data
# Out:
# [{'id': '0', 'question': 'cause', 'premise': 'A felhajtón parkoltam.', 'choice1': 'A garázs nyitva volt.', 'choice2': 'A garázs tele volt.', 'label': '2'}, {'id': '1', 'question': 'cause', 'premise': 'A fürdőt elöntötte a víz.', 'choice1': 'A WC túlcsordult.', 'choice2': 'Elromlott a bojler.', 'label': '1'}, {'id': '2', 'question': 'effect', 'premise': 'A futó megérezte a versenytársa közeledését.', 'choice1': 'Kiesett a versenyből.', 'choice2': 'Felgyorsította a tempót.', 'label': '2'}, {'id': '3', 'question': 'effect', 'label': '1', 'premise': 'A csap alá tettem a kezem.', 'choice1': 'Leöblítettem a kezemről a szappant.', 'choice2': 'A víz az arcomba spriccelt.'}, {'id': '4', 'question': 'effect', 'label': '2', 'premise': 'A beteg kiszáradt.', 'choice1': 'A nővér tesztelte a reflexeit.', 'choice2': 'A nővér infúziót adott neki.'}, {'id': '5', 'question': 'effect', 'premise': 'A férj bűnösnek érezte magát, amiért megcsalta a feleségét.', 'choice1': 'Hűtlenséggel vádolta.', 'choice2'
# ...

# %%
# !pip install jsonlines
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
import jsonlines
path = "/Users/mathias/Desktop/Project_NLP_MVA_23/Datasets/HuCoPA/data/train.json"

with open(path, encoding='utf8') as json_file:
    json_data = json.load(json_file)
    print(json_data)
with jsonlines.open('/Users/mathias/Desktop/Project_NLP_MVA_23/Datasets/HuCoPA/data/train.jsonl', 'w') as writer:
    writer.write_all(json_data)

path = "/Users/mathias/Desktop/Project_NLP_MVA_23/Datasets/HuCoPA/data/test.json"

with open(path, encoding='utf8') as json_file:
    json_data = json.load(json_file)
    print(json_data)
with jsonlines.open('/Users/mathias/Desktop/Project_NLP_MVA_23/Datasets/HuCoPA/data/test.jsonl', 'w') as writer:
    writer.write_all(json_data)

path = "/Users/mathias/Desktop/Project_NLP_MVA_23/Datasets/HuCoPA/data/unlabelled.json"

with open(path, encoding='utf8') as json_file:
    json_data = json.load(json_file)
    print(json_data)
with jsonlines.open('/Users/mathias/Desktop/Project_NLP_MVA_23/Datasets/HuCoPA/data/unlabeled.jsonl', 'w') as writer:
    writer.write_all(json_data)

path = "/Users/mathias/Desktop/Project_NLP_MVA_23/Datasets/HuCoPA/data/val.json"

with open(path, encoding='utf8') as json_file:
    json_data = json.load(json_file)
    print(json_data)
with jsonlines.open('/Users/mathias/Desktop/Project_NLP_MVA_23/Datasets/HuCoPA/data/val.jsonl', 'w') as writer:
    writer.write_all(json_data)
# Out:
# [{'id': '36', 'question': 'effect', 'label': '1', 'premise': 'Fizettem a vámszedőnek.', 'choice1': 'Átengedett a fizetőkapun.', 'choice2': 'Őrizetbe vett a fizetőkapunál.'}, {'id': '178', 'question': 'effect', 'label': '2', 'premise': 'Cukrot tettem a kávéba.', 'choice1': 'A kávénak erős illata lett.', 'choice2': 'A kávénak édes íze lett.'}, {'id': '251', 'question': 'effect', 'label': '2', 'premise': 'A férfi beverte a fejét.', 'choice1': 'Elmerült a gondolataiban.', 'choice2': 'Agyrázkódása lett.'}, {'id': '288', 'question': 'effect', 'label': '2', 'premise': 'A lány talált egy bogarat a müzlijében.', 'choice1': 'Tejet öntött a tálba.', 'choice2': 'Elment az étvágya.'}, {'id': '319', 'question': 'cause', 'label': '1', 'premise': 'Az anya szemmagasságba került a fiával.', 'choice1': 'Leguggolt.', 'choice2': 'Fogta a kezét.'}, {'id': '283', 'question': 'effect', 'label': '2', 'premise': 'A gyermek panaszkodott, hogy ki kell mennie a mosdóba.', 'choice1': 'Az apja üdítőt adott neki in
# ...
